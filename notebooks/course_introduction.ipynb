# %% [markdown]
# # Feature Showcase and Subsections
#
# This notebook demonstrates common Jupyter Book content patterns.

# %% [markdown]
# ## Subsection: Markdown and HTML Rendering
#
# You can use standard Markdown, tables, and inline HTML.
#
# <div style="padding:8px;border:1px solid #ccc;border-radius:6px;">
# <strong>HTML block</strong>: This is rendered inside the notebook page.
# </div>

# %% [markdown]
# ## Subsection: LaTeX Support
#
# Inline equation: $e^{i\pi} + 1 = 0$
#
# Block equation:
#
# $$
# \int_0^1 x^2 dx = \frac{1}{3}
# $$

# %%
# Python code output example
values = [1, 2, 3, 4, 5]
squared = [v**2 for v in values]
print('Values :', values)
print('Squares:', squared)

# %%
# Visualization example
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o')
plt.title('Sample Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
